# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Accept_the_Strings_Which_Contains_all_Vowels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "hey hii how are "
v = set('aeiou')
if v.issubset(set(s.lower())):
    print("True")
else:
    print("False")
# Out:
# False
