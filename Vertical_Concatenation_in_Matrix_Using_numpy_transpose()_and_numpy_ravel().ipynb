# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Vertical_Concatenation_in_Matrix_Using_numpy_transpose()_and_numpy_ravel().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import zip_longest
t1 = [["Gfg", "good"], ["is", "for"], ["Best"]]
res = ["".join(col) for col in zip_longest(*t1, fillvalue="")]
print( str(res))
# Out:
# ['GfgisBest', 'goodfor']
