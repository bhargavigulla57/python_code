# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Words_Frequency_in_String_Shorthands_Using_collections_Counter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
s = "hello world hello everyone"
res = Counter(s.split())
print(res)
# Out:
# Counter({'hello': 2, 'world': 1, 'everyone': 1})
