# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Reverse_the_Content_of_a_File_using_Stack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle

data = [
    {'name': 'geek', 'score': 10},
    {'platform': 'GeeksforGeeks', 'rating': 4.8},
    {'username': 'supergeek', 'active': False}
]

with open('data.pkl', 'wb') as file:
    pickle.dump(data, file)
