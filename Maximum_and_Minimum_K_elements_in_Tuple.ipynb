# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Maximum_and_Minimum_K_elements_in_Tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

tup = (5, 20, 3, 7, 6, 8)
K = 2

s = heapq.nsmallest(K, tup)
l = heapq.nlargest(K, tup)

print(s)
print(l)
# Out:
# [3, 5]
# [20, 8]
