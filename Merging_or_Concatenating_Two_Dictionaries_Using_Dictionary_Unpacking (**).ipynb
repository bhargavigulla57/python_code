# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Merging_or_Concatenating_Two_Dictionaries_Using_Dictionary_Unpacking%20(**).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d1 = {'x': 1, 'y': 2}
d2 = {'y': 3, 'z': 4}

d3 = {**d1, **d2}
print(d3)
# Out:
# {'x': 1, 'y': 3, 'z': 4}
