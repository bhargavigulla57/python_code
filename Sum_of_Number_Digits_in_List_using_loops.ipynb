# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Sum_of_Number_Digits_in_List_using_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [123, 456, 789]
res = []

for val in a:
    total = 0
    while val > 0:
        total += val % 10
        val //= 10
    res.append(total)

print(res)
# Out:
# [6, 15, 24]
