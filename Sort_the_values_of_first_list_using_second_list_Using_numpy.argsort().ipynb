# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Sort_the_values_of_first_list_using_second_list_Using_numpy.argsort().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

a = ['a', 'b', 'c', 'd']
b = [3, 1, 4, 2]
res = [a[i] for i in np.argsort(b)]
print(res)
# Out:
# ['b', 'd', 'a', 'c']
