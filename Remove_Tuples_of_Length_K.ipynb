# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Remove_Tuples_of_Length_K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t1 = [(4, 5), (4, ), (8, 6, 7), (1, ), (3, 4, 6, 7)]
K = 1
res = [ele for ele in t1 if len(ele) != K]
print(str(res))
# Out:
# [(4, 5), (8, 6, 7), (3, 4, 6, 7)]
