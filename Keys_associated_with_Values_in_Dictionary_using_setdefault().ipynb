# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Keys_associated_with_Values_in_Dictionary_using_setdefault().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = {'gfg': [1, 2, 3], 'is': [1, 4], 'best': [4, 2]}

res = {}
for key, vals in d.items():
    for v in vals:
        res.setdefault(v, []).append(key)

print( res)
# Out:
# {1: ['gfg', 'is'], 2: ['gfg', 'best'], 3: ['gfg'], 4: ['is', 'best']}
