# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/checking_if_a_string_contains_any_special_character.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python3 program to check if a string
# contains any special character

# import required package
import re

# Function checks if the string
# contains any special character
def run(string):

    # Make own character set and pass
    # this as argument in compile method
    regex = re.compile('[@_!#$%^&*()<>?/\|}{~:]')

    # Pass the string in search
    # method of regex object.
    if(regex.search(string) == None):
        print("String is accepted")

    else:
        print("String is not accepted.")


# Driver Code
if __name__ == '__main__' :

    # Enter the string
    string = "Geeks$For$Geeks"

    # calling run function
    run(string)
# Out:
# String is not accepted.
# <>:13: SyntaxWarning: invalid escape sequence '\|'
# <>:13: SyntaxWarning: invalid escape sequence '\|'
# /tmp/ipython-input-2024034124.py:13: SyntaxWarning: invalid escape sequence '\|'
#   regex = re.compile('[@_!#$%^&*()<>?/\|}{~:]')
