# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Reverse_the_Content_of_a_File_using_Stack_using_pickel_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
try:
    with open("data.pkl", "rb") as f:
        dict_list = pickle.load(f)

    for d in dict_list:
        print(d)

except Exception as e:
    print("Error:", e)
# Out:
# Error: [Errno 2] No such file or directory: 'data.pkl'
