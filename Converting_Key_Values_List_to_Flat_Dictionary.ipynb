# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Converting_Key_Values_List_to_Flat_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [("name", "Emma"), ("age", 25), ("city", "New York")]
res = dict(a)
print(res)
# Out:
# {'name': 'Emma', 'age': 25, 'city': 'New York'}
