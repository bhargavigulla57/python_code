# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Print_Anagrams_together_in_Python_using_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = ['bat', 'nat', 'tan', 'ate', 'eat', 'tea']
res = {}

for word in a:
    key = ''.join(sorted(word))
    res[key] = res.get(key, []) + [word]

output = list(res.values())
print(output)
# Out:
# [['bat'], ['nat', 'tan'], ['ate', 'eat', 'tea']]
