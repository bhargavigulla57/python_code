# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Vertical_Concatenation_in_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
t1 = [["Gfg", "good"], ["is", "for"], ["Best"]]
df = pd.DataFrame(t1)
res = df.fillna('').apply(''.join)
print(list(res))
# Out:
# ['GfgisBest', 'goodfor']
