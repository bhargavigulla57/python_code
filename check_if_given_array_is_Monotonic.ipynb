# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/check_if_given_array_is_Monotonic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr = [6, 5, 4, 4]
n = len(arr)

incr = all(arr[i] <= arr[i+1] for i in range(n-1))
decr = all(arr[i] >= arr[i+1] for i in range(n-1))

print(incr or decr)
# Out:
# True
