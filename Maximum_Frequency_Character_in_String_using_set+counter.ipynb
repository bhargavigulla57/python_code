# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Maximum_Frequency_Character_in_String_using_set%2Bcounter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
s = "hello world"
max_char = max(set(s), key=Counter(s).get)
print(max_char)
# Out:
# l
