# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Remove_Empty_Tuples_from_a_List_using_filter().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [(1, 2), (), (3, 4), (), (5,)]
res = list(filter(None, a))
print(res)
# Out:
# [(1, 2), (3, 4), (5,)]
