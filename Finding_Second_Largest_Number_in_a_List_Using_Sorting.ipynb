# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Finding_Second_Largest_Number_in_a_List_Using_Sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [10, 20, 4, 45, 99]
a.sort(reverse=True)
print(a[1])
# Out:
# 45
