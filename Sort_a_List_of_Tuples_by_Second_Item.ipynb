# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Sort_a_List_of_Tuples_by_Second_Item.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from operator import itemgetter
a = [(7, 5), (3, 8), (2, 6)]
res = sorted(a, key=itemgetter(1))
print(res)
