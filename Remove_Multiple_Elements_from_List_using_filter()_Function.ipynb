# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Remove_Multiple_Elements_from_List_using_filter()_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [10, 20, 30, 40, 50, 60, 70]
remove = {20, 40, 60}
a = list(filter(lambda x: x not in remove, a))
print(a)
# Out:
# [10, 30, 50, 70]
