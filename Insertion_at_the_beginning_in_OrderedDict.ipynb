# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Insertion_at_the_beginning_in_OrderedDict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import OrderedDict
d = OrderedDict([('a', 1), ('b', 2)])
d.update({'c': 3})
d.move_to_end('c', last=False)
print(d)
# Out:
# OrderedDict({'c': 3, 'a': 1, 'b': 2})
