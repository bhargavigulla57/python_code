# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Sorting_Python_Dictionary_by_Key_or_Value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = {'watermelon': 1, 'apple': 2, 'banana': 3}
asc = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
print(asc)
# Out:
# {'watermelon': 1, 'apple': 2, 'banana': 3}
