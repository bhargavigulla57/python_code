# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Sort_the_values_of_first_list_using_second_list_Using_sorted()_with_a_lambda_key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = ['m', 'n', 'o', 'p']
b = [4, 1, 3, 2]

res = sorted(a, key=lambda x: b[a.index(x)])
print(res)
# Out:
# ['n', 'p', 'o', 'm']
