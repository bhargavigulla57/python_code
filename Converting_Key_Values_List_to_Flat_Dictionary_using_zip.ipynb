# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Converting_Key_Values_List_to_Flat_Dictionary_using_zip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = ["name", "age", "city"]  # List of keys
b = ["Emma", 25, "New York"]  # List of values
res = dict(zip(a, b))
print(res)
# Out:
# {'name': 'Emma', 'age': 25, 'city': 'New York'}
