# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Least_Frequent_Character_in_String_Using_str.count().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "have a great day"
res = min(s, key=lambda char: s.count(char))
print(str(res))
# Out:
# h
