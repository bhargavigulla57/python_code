# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Least_Frequent_Character_in_String_Using_shorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "having a great day"
d = {}

for char in s:
    d[char] = d.get(char, 0) + 1

sorted_freq = sorted(d.items(), key=lambda item: item[1])
res = sorted_freq[0][0]
print(res)
# Out:
# h
