# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/printing_positive_numbers_in_a_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a = np.array([-10, 15, 0, 20, -5, 30, -2])
res = a[a > 0]
print(res)
# Out:
# [15 20 30]
