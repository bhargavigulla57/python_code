# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Replace_all_Occurrences_of_a_Substring_in_a_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "python java python html python"
res = a.replace("python", "c++")
print(res)
# Out:
# c++ java c++ html c++
