# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/printing_positive_numbers_in_a_list_Comprehension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [-10, 15, 0, 20, -5, 30, -2]
res = [i for i in a if i > 0]
print(res)
# Out:
# [15, 20, 30]
