# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Remove_All_Duplicates_from_a_Given_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "hopeisgood"
res = "".join(dict.fromkeys(s))
print(res)
# Out:
# hopeisgd
