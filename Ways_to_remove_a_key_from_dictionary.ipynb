# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Ways_to_remove_a_key_from_dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = {"name": "Nikki", "age": 25, "city": "New York"}
rv = a.pop("age")
print(a)
print(rv)
# Out:
# {'name': 'Nikki', 'city': 'New York'}
# 25
