# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Check_if_element_exists_in_list_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [10, 20, 30, 40, 50]

if 30 in a:
    print("Element exists in the list")
else:
    print("Element does not exist")
# Out:
# Element exists in the list

# %%
a = [10,20,30,40,50]

if 60 in a:
  print("Element exists in the list")
else:
  print("Element does not exist")
# Out:
# Element does not exist
