# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/finding_simple_interest_Using_list%20comprehension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p, t, r = 8, 6, 8

si = [p * t * r / 100][0]
print(si)
# Out:
# 3.84
