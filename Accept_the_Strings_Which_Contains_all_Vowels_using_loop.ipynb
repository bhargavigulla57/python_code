# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Accept_the_Strings_Which_Contains_all_Vowels_using_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "education"
v = 'aeiou'
a = set()
for char in s.lower():
    if char in v:
        a.add(char)
    if len(a) == 5:
        print("True")
        break
else:
    print("False")
# Out:
# True
