# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= input("enter  a data to cheeck a palindrome")
a1=a[::-1]
if a == a1:
  print("its a palindrome")
else:
  print("its not a palindrome")
# Out:
# enter  a data to cheeck a palindrome76667
# its a palindrome
