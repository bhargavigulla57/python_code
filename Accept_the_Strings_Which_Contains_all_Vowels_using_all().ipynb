# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Accept_the_Strings_Which_Contains_all_Vowels_using_all().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "hey hii how are you"
v = 'aeiou'
if all(i in s.lower() for i in v):
    print("True")
else:
    print("False")
# Out:
# True
