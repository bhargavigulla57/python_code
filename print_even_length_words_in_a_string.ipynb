# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/print_even_length_words_in_a_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "This is a python language"
wrds = s.split()
even_wrds = [w for w in wrds if len(w) % 2 == 0]
res = " ".join(even_wrds)
print(res)
# Out:
# This is python language
