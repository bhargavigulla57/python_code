# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Finding_Uncommon_Words_from_Two_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
s1 = "have a grat day"
s2 = "having a great day can make us happy"

count = Counter(s1.split()) + Counter(s2.split())
res = [word for word in count if count[word] == 1]
print(res)
# Out:
# ['have', 'grat', 'having', 'great', 'can', 'make', 'us', 'happy']
