# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Append_Dictionary_Keys_and_Values_(In_order)_in_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
keys = ["name", "age", "city"]
values = ["Robin", 30, "New York"]
d = dict(zip(keys, values))
print(d)
# Out:
# {'name': 'Robin', 'age': 30, 'city': 'New York'}
