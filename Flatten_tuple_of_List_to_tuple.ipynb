# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Flatten_tuple_of_List_to_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import chain
tup = ([5, 6], [6, 7, 8, 9], [3])
res = tuple(chain.from_iterable(tup))
print(res)
# Out:
# (5, 6, 6, 7, 8, 9, 3)
