# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/finding_the_size_of_tuple_Using%20_memoryview().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tup = (0, 1, 2,'a', 3)
res = memoryview(bytearray(str(tup),'utf-8'))
print(res.nbytes)
# Out:
# 17
