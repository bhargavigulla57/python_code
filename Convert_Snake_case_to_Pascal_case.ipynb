# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Convert_Snake_case_to_Pascal_case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s= 'morningwalk_is_best'
res = ''.join(word.capitalize() for word in s.split('_'))
print(res)
# Out:
# MorningwalkIsBest
