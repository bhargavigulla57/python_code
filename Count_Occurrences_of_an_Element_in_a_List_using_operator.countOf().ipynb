# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Count_Occurrences_of_an_Element_in_a_List_using_operator.countOf().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import operator
a = [1, 3, 2, 6, 3, 2, 8, 2, 9, 2, 7, 3]
print(operator.countOf(a, 3))
# Out:
# 3
