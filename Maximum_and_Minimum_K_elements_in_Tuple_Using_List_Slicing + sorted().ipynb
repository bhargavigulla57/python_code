# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Maximum_and_Minimum_K_elements_in_Tuple_Using_List_Slicing%20%2B%20sorted().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tup = (5, 20, 3, 7, 6, 8)
K = 2

temp = sorted(tup)
mi = temp[:K]
ma = temp[-K:]

print(mi)
print(ma)
# Out:
# [3, 5]
# [8, 20]
