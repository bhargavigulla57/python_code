# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Split_and_join_the_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "Hello, how are you?"
b = a.split()       # Split by space
c = "-".join(b)     # Join with hyphen

print(b)
print(c)
# Out:
# ['Hello,', 'how', 'are', 'you?']
# Hello,-how-are-you?
