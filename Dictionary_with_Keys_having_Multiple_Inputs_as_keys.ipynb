# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Dictionary_with_Keys_having_Multiple_Inputs_as_keys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict = {}

dict[(1, 2, 3)] = "First"
dict[(4, 5, 6)] = "Second"

print(dict[(1, 2, 3)])
print(dict[(4, 5, 6)])

print(dict)
# Out:
# First
# Second
# {(1, 2, 3): 'First', (4, 5, 6): 'Second'}
