# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Print_Anagrams_together_in_Python_using_List_and_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter, defaultdict

a = ['bat', 'nat', 'tan', 'ate', 'eat', 'tea']
res = defaultdict(list)

for word in a:
    key = tuple(sorted(Counter(word).items()))
    res[key].append(word)

print(list(res.values()))
# Out:
# [['bat'], ['nat', 'tan'], ['ate', 'eat', 'tea']]
