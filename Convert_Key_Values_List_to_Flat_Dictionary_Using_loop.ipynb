# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Convert_Key_Values_List_to_Flat_Dictionary_Using_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [("name", "Emma"), ("age", 25), ("city", "New York")]
b = {}
for key, value in a:
    b[key] = value

print(b)
# Out:
# {'name': 'Emma', 'age': 25, 'city': 'New York'}
