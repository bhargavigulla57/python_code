# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Finding_Second_Largest_Number_in_a_List_using_heapq_nlargest().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq
a = [10, 20, 4, 45, 99]
res = heapq.nlargest(2, a)
print(res[1])
# Out:
# 45
