# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Untitled57.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n =6

for i in range(0,6):
  for j in range(0,n+i):
    Print("* ",end="")
    i=i+1
  print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-172058327.py in <cell line: 0>()
#       3 for i in range(0,6):
#       4   for j in range(0,n+i):
# ----> 5     Print("* ",end="")
#       6     i=i+1
#       7   print(i)
#
# NameError: name 'Print' is not defined
