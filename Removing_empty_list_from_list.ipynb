# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Removing_empty_list_from_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [[1, 2], [], [3, 4], [], [5]]
res = [b for b in a if b]
print(res)
# Out:
# [[1, 2], [3, 4], [5]]
