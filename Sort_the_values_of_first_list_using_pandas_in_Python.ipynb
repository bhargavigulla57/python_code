# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Sort_the_values_of_first_list_using_pandas_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

a = ['a', 'b', 'c', 'd']
b = [3, 1, 4, 2]

df = pd.DataFrame({'a': a, 'b': b})
res = df.sort_values('b')['a'].tolist()
print(res)
# Out:
# ['b', 'd', 'a', 'c']
