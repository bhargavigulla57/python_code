# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/finding_the_sum_of_all_items_in_a_dictionary_Using_list_comprehension_and_sum().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = {'a': 100, 'b': 200, 'c': 300}
res = sum([d[key] for key in d])
print(res)
# Out:
# 600
