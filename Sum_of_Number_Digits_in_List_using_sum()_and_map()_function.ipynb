# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/Sum_of_Number_Digits_in_List_using_sum()_and_map()_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [123, 456, 789]
res = [sum(map(int, str(val))) for val in a]
print(res)
# Out:
# [6, 15, 24]
