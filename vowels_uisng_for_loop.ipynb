# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavigulla57/python_code/blob/main/vowels_uisng_for_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a ="BHArgavi"
b = "AEIOUaeiou"
for i in a:
  if i in b:
    print("{} a vowel".format(i))
  else:
    print("{} not a vowel".format(i))
# Out:
# B not a vowel
# H not a vowel
# A a vowel
# r not a vowel
# g not a vowel
# a a vowel
# v not a vowel
# i a vowel
